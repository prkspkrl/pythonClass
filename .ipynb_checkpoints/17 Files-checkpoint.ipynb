# %%
try:
    b = open('Classdata.csv','x')
    b.close()
except:
    pass

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv')
df.head(5)
# df.tail()
# Out:
#    sn     name  age         add       phone
# 0   1      Ram   45   Kathmandu  9849967446
# 1   2    Sabin   25    Lalitpur  9849937143
# 2   3    Nabin   33   Kupondole  9847458523
# 3   4     Hari   15   Shankamul  9844767585
# 4   5  Manisha   23  Chujathati    14165856

# %%
 df.tail(3)
# Out:
#    sn       name  age         add      phone
# 4   5    Manisha   23  Chujathati   14165856
# 5   6      Mohan   29     Pyuthan  984658546
# 6   7  Tribhuwan   32     pyuthan  984775862

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df
# Out:
#          name  age         add       phone
# sn
# 1         Ram   45   Kathmandu  9849967446
# 2       Sabin   25    Lalitpur  9849937143
# 3       Nabin   33   Kupondole  9847458523
# 4        Hari   15   Shankamul  9844767585
# 5     Manisha   23  Chujathati    14165856
# 6       Mohan   29     Pyuthan   984658546
# 7   Tribhuwan   32     pyuthan   984775862

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df.iloc[0:4] #for row
# Out:
#      name  age        add       phone
# sn
# 1     Ram   45  Kathmandu  9849967446
# 2   Sabin   25   Lalitpur  9849937143
# 3   Nabin   33  Kupondole  9847458523
# 4    Hari   15  Shankamul  9844767585

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df.iloc[0:4,0:3] #last 0:3 is colume filter
# Out:
#      name  age        add
# sn
# 1     Ram   45  Kathmandu
# 2   Sabin   25   Lalitpur
# 3   Nabin   33  Kupondole
# 4    Hari   15  Shankamul

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn',usecols=['sn','name','add'])
df
# Out:
#          name         add
# sn
# 1         Ram   Kathmandu
# 2       Sabin    Lalitpur
# 3       Nabin   Kupondole
# 4        Hari   Shankamul
# 5     Manisha  Chujathati
# 6       Mohan     Pyuthan
# 7   Tribhuwan     pyuthan

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df.loc[2:6]
# Out:
#        name  age         add       phone
# sn
# 2     Sabin   25    Lalitpur  9849937143
# 3     Nabin   33   Kupondole  9847458523
# 4      Hari   15   Shankamul  9844767585
# 5   Manisha   23  Chujathati    14165856
# 6     Mohan   29     Pyuthan   984658546

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'name')
df.loc['Nabin':'Mohan'] #Make unique values don't use name
# Out:
#          sn  age         add       phone
# name
# Nabin     3   33   Kupondole  9847458523
# Hari      4   15   Shankamul  9844767585
# Manisha   5   23  Chujathati    14165856
# Mohan     6   29     Pyuthan   984658546

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df[df['name'] == 'Hari']
# Out:
#     name  age        add       phone
# sn
# 4   Hari   15  Shankamul  9844767585

# %%
import pandas as pd
df = pd.read_csv('Classdata.csv',index_col = 'sn')
df[df['age'] < 30]
# Out:
#        name  age         add       phone
# sn
# 2     Sabin   25    Lalitpur  9849937143
# 4      Hari   15   Shankamul  9844767585
# 5   Manisha   23  Chujathati    14165856
# 6     Mohan   29     Pyuthan   984658546
