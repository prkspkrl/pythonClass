# %%
import requests 

from bs4 import BeautifulSoup

url ='http://www.nepalstock.com/main/todays_price/index/1/'

r = requests.get(url) 

# print(r.status_code)

soup = BeautifulSoup(r.text,'html.parser') 

# print(soup)

stock_table = soup.find('tr',class_ = 'unique')

# print(stock_table)

for stock in stock_table.find_all('td'):
    x = stock.text.strip()
    print(x)
    
stock_table = soup.find('tr')    
stock_table
# Out:
# S.N.
# Traded Companies
# No. Of Transaction
# Max Price
# Min Price
# Closing Price
# Traded Shares
# Amount
# Previous Closing
# Difference Rs.
# <tr align="right">
# <td colspan="10">
# <label class="pull-left">As of 2022-10-23 15:00:00</label>
# <form action="http://www.nepalstock.com/todaysprice" id="news_info-filter" method="POST" name="news_info-filter">
# <label> Select Date
#                     <input id="startDateToday" name="startDate" readonly="" type="date" value="">
# </input></label>
# <label>
# <select class="stock-symbol" id="stock-symbol" name="stock-symbol">
# <option value="">Stock Symbol</option>
# ...

# %%
#     first_stock = stock.find('td')
    print(stock)
    
    
#     rows = stock.find_all('td')
#     for row in rows:
#         first_stock = row.find('td',class_ = 'icon-asc sorter')
#         print(first_stock)

# %%
# ab = pd.read_csv('stock.csv', encoding = 'unicode_escape') 
# ab
# Out:
#                                                                                       S.N.  \
# 1                               10% Prime Debenture 2088                               5.0
# 2                               10.5 % NEPAL INVESTMENT DEBENTURE 2082                 1.0
# 3                               12% ICFC Finance Limited Debenture 2083                1.0
# 4                               Aarambha Chautari Laghubitta Bittiya Sanstha Li...    23.0
# 5                               Agricultural Development Bank Limited                164.0
# 6                               Ankhu Khola Jalvidhyut Company Ltd                    65.0
# 7                               Api Power Company Ltd.                               179.0
# 8                               Arun Kabeli Power Ltd.                               135.0
# 9                               Arun Valley Hydropower Development Co. Ltd.           81.0
# ...

# %%
#hya new start
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('http://www.nepalstock.com/main/todays_price/index/1/', 'html.parser')
soup=requests.get(url)
# print(soup)
code = soup.text
# print(code)
lxml_code = BeautifulSoup(code, "lxml")
# print(lxml_code)


table_code = lxml_code.table
# tags = table_code.find('tr',class_ = 'unique')

tags = table_code.find_all('tr')
tags



raw_data = []
for tag in tags:
 
    x = tag.text.split('\n')[1:-1]
    if x[0] != "" :
        raw_data.append(x) 
#         print(raw_data)
 


import csv
with open('ram.csv','w') as file:
    x = csv.writer(file)
    x.writerows(raw_data)
    
    
import csv
import pandas as pd
df = pd.read_csv('ram.csv',encoding='latin1')
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
#                                                                                       S.N.  \
# 1                               10% Prime Debenture 2088                               5.0
# 2                               10.5 % NEPAL INVESTMENT DEBENTURE 2082                 1.0
# 3                               12% ICFC Finance Limited Debenture 2083                1.0
# 4                               Aarambha Chautari Laghubitta Bittiya Sanstha Li...    23.0
# 5                               Agricultural Development Bank Limited                164.0
# 6                               Ankhu Khola Jalvidhyut Company Ltd                    65.0
# ...

# %%
url = BeautifulSoup('https://www.nepalstock.com/main/todays_price/index/1/', 'html.parser')
soup=requests.get(url)
print(soup)
import time
while(True):
    print(soup)
    time.sleep(10)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
