# %%
class Info:
    def __init__(self,name,age,add):
        self.name =name
        self.age =age
        self.add =add
    
    def details(self):
        return f"Hello world {self.name}{self.age}{self.add}"
        
class Data(Info):
    def data(self):
        print(f"Hello there {self.name}{self.age}{self.add}")
        print(super().details())

obj = Data("Ram",34,"ktm")
obj.data()
# Out:
# Hello there Ram34ktm
# Hello world Ram34ktm

# %%
class Info:
    def __init__(self,age,add):
        self.age =age
        self.add =add
        
        
    def details(self):
        return f"Hello world {self.name}{self.age}{self.add}"
        
class Data(Info):
    def __init__(self,name,age,add):
        self.name =name
        Info.__init__(self,age,add)
    
    
    def data(self):
        print(f"Hello there {self.name}{self.age}{self.add}")
        print(super().details())

obj = Data("Ram",34,"ktm")
obj.data()
# Out:
# Hello there Ram34ktm
# Hello world Ram34ktm

# %%
class Age:
    def __init__(self,age):
        self.age =age
        
class Add:
    def __init__(self,add):
        self.add =add        

        
class Data(Age,Add):
    def __init__(self,name,age,add):
        self.name =name
        Age.__init__(self,age)
        Add.__init__(self,add)
    
    
    def data(self):
        print(f"Hello there {self.name}{self.age}{self.add}")

obj = Data("Ram",34,"ktm")
obj.data()
# Out:
# Hello there Ram34ktm

# %%
class Age:
    def __init__(self,age):
        self.age =age
        
class Add:
    def __init__(self,add):
        self.add =add        

        
class Data(Age,Add):
    def __init__(self,name,age,add):
        self.name =name
        Age.__init__(self,age)
        Add.__init__(self,add)
    
    
    def data(self):
        print(f"Hello there {self.name}{self.age}{self.add}")

obj = Data("Ram",34,"ktm")
obj1 = Age(40)
obj.data()
print(obj1.age)
# Out:
# Hello there Ram34ktm
# 40

# %%
class Age:
    def __init__(self,age):
        self.age =age
    def age(self):
        return age
        
class Add(Age):
    def __init__(self,age,add):
        self.add =add 
        Age.__init__(self,age)
    def add(self):
        return self.add
        

        
class Data(Add):
    def __init__(self,name,age,add):
        self.name =name
        Age.__init__(self,age)
    
    
    def data(self):
        print(f"Hello there {self.name}{self.age}{self.add}")

obj = Data("Ram",34,"ktm")
obj.data()
# Out:
# Hello there Ram34<bound method Add.add of <__main__.Data object at 0x000002237BE81B50>>

# %%
# Public
class Info:
    def __init__(self):
        self.name = "Ram"
        self.add = "bara"
        self.age = 45
        
obj = Info()
print(obj.name)
print(obj.age)
print(obj.add)
# Out:
# Ram
# 45
# bara

# %%
# protected
class Info:
    def __init__(self):
        self._name = "Ram"
        self._add = "bara"
        self._age = 45  #proteted by _ symbol
        
obj = Info()
print(obj._name)
print(obj._age)
print(obj._add)
# Out:
# Ram
# 45
# bara

# %%
# Access Private Attribute in pyuthon
class Info:
    def __init__(self):
        self.__name = "Ram"
        self.__add = "bara"
        self.__age = 45  #private by _ symbol
        
obj = Info()
print(obj._Info__name)
print(obj._Info__age)
print(obj._Info__add)
# Out:
# Ram
# 45
# bara

# %% [markdown]
# # Ues of private, protected and public

# %%
class Info:
    def __init__(self,name,age,add):
        self.name =name
        self._age =age
        self.__add =add
    
    def details(self):
        return f"Hello world {self.name}{self._age}{self.__add}"
        
class Data(Info):
    def data(self):
        print(f"Hello there {self.name}{self._age}")
        print(super().details())

obj = Data("Ram",34,"ktm")
obj.data()
# Out:
# Hello there Ram34
# Hello world Ram34ktm
