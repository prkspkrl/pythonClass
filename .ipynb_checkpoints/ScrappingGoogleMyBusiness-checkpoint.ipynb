# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.google.com/search?q=delivery+company+in+nepal&biw=1821&bih=833&sz=0&tbm=lcl&sxsrf=ALiCzsZbgtemo9HXSZheqQDi3Pivrhl7IA%3A1666026260994&ei=FItNY5mIPKubseMPzNK7oAo&oq=delivery+company+in+&gs_lcp=Cg1nd3Mtd2l6LWxvY2FsEAMYADIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQ6BAgjECc6BggAEAUQHjoHCCMQyQMQJzoGCAAQFhAeUJYSWLUWYO8iaABwAHgAgAHZAYgBlgiSAQUwLjUuMZgBAKABAcABAQ&sclient=gws-wiz-local#rlfi=hd:;si:;mv:[[27.749352199999997,85.3577372],[27.6738966,85.300455]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!2m1!1e3!2m4!1e17!4m2!17m1!1e2!3sIAE,lf:1,lf_ui:3', 'html.parser')
soup=requests.get(url)
# print(soup)
code = soup.text


lxml_code = BeautifulSoup(code, "lxml")
lxml_code
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="ne"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>delivery company in nepal - Google खोजी</title><script nonce="rwKgFVhYXaZ-FVwza2ptJw">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...
