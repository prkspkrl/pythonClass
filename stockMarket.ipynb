# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('http://www.nepalstock.com/main/todays_price/index/1/', 'html.parser')
soup=requests.get(url)
# print(soup)
code = soup.text
# print(code)
lxml_code = BeautifulSoup(code, "lxml")
print(lxml_code)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <!DOCTYPE HTML>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Nepal Stock Exchange Ltd.</title>
# <meta content="NEPSE Official Website" name="title"/>
# <meta content="This is NEPSE Official Website" http-equiv="description" name="description"/>
# <meta content="This is NEPSE Official Website" http-equiv="keywords" name="keywords"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- Bootstrap core CSS -->
# <link href="http://www.nepalstock.com/css/reset.css" rel="stylesheet"/>
# ...

# %%
table_code = lxml_code.table
tags = table_code.find_all('tr')
tags
# Out:
# [<tr align="right">
#  <td colspan="10">
#  <label class="pull-left">As of 2022-10-17 15:00:00</label>
#  <form action="http://www.nepalstock.com/todaysprice" id="news_info-filter" method="POST" name="news_info-filter">
#  <label> Select Date
#                      <input id="startDateToday" name="startDate" readonly="" type="date" value=""/>
#  </label>
#  <label>
#  <select class="stock-symbol" id="stock-symbol" name="stock-symbol">
#  <option value="">Stock Symbol</option>
# ...

# %%
# tagbs = table_code.find_all('td')
# tagbs

# %%
raw_data = []
for tag in tags:
    
    x = tag.text.split('\n')[1:-1]
    if x[0] != "" and x[5] !="":
        raw_data.append(x) 
    print(raw_data)
#     print(x[0])
# Out:
# []
# [['S.N.', 'Traded Companies', 'No. Of Transaction', 'Max Price', 'Min Price', 'Closing Price', 'Traded Shares', 'Amount', 'Previous Closing', 'Difference Rs.']]
# [['S.N.', 'Traded Companies', 'No. Of Transaction', 'Max Price', 'Min Price', 'Closing Price', 'Traded Shares', 'Amount', 'Previous Closing', 'Difference Rs.'], ['1', '10% Prime Debenture 2088', '4', '840.00', '832.10', '839.10', '105.00', '87830.00', '831.00', '8.10\xa0', '                                            ', '']]
# ...

# %%
import csv
with open('stock.csv','w') as file:
    x = csv.writer(file)
    x.writerows(raw_data)

# %%
#Data vesulises
import pandas as pd
df = pd.read_csv('stock.csv',encoding='latin1',index_col=None)
df
# Out:
#                                                        S.N.  Traded Companies  \
# 1  10% Prime Debenture 2088                               4             840.0
# 2  10.5 % NEPAL INVESTMENT DEBENTURE 2082                 1             911.4
# 3  8.5% BOK Debenture 2086                                2             756.6
# 4  8.5% Sanima Debenture 2087                             1             750.0
# 5  8.75 % Prime Debenture 2085                            1             785.0
# 6  Aarambha Chautari Laghubitta Bittiya Sanstha Li...    21             719.0
# 7  Agricultural Development Bank Limited                205             321.0
# 8  Ankhu Khola Jalvidhyut Company Ltd                    88             173.0
# 9  Api Power Company Ltd.                               236             212.0
# 10 Arun Kabeli Power Ltd.                               114             385.0
# 11 Arun Valley Hydropower Development Co. Ltd.          134             277.0
# ...

# %%
stock_name = list(df['Traded Companies'][0:20])
Max_Price = list(df['Max Price'][0:10])
# total_cases = []
# for i in total_case:
#     x = int(i.replace(',',''))
#     total_cases.append(x)
# print(total_cases)
# print(country)
stock_name
# Out:
# [840.0,
#  911.4,
#  756.6,
#  750.0,
#  785.0,
#  719.0,
#  321.0,
#  173.0,
#  212.0,
#  385.0,
#  277.0,
#  935.0,
#  441.0,
#  808.0,
#  249.9,
#  216.0,
#  331.5,
#  342.9,
#  3200.0,
#  12299.0]

# %%
# import plotly.express as px

# # df = px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")
# fig = px.bar(df, y='pop', x='country', text_auto='.2s',
#             title="Default: various text sizes, positions and angles")
# fig.show()
