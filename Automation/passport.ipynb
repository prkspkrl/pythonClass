# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import ipdb
web = webdriver.Edge()


web.get('https://emrtds.nepalpassport.gov.np/')

time.sleep(3)

first_issue = web.find_element("xpath", '/html/body/app-root/app-landing-page/app-iups-services/section/div/div[2]/div/div/div[1]/div')
first_issue.click()
time.sleep(5)
Ordinary_page = web.find_element("xpath", '/html/body/app-root/app-request-service/section[2]/div/div/div[1]/div/form/div/div/div[2]/div[1]/div[1]/label')
Ordinary_page.click()
time.sleep(5)
submit = web.find_element("xpath", '/html/body/app-root/app-request-service/section[2]/div/div/div[1]/div/form/div/div/div[3]/div[2]/a')
submit.click()

policy_agree = web.find_element("xpath", '/html/body/div/div[2]/div/mat-dialog-container/app-consent-dialog/div/div[3]/a[1]')
policy_agree.click()

time.sleep(5)
drop_down = web.find_element("xpath", "/html/body/app-root/app-appointment/section[2]/div/div[2]/div[1]/div/div[2]/div/mat-select/div/div[1]")
drop_down.click()

drop_down_select = web.find_element("xpath", "/html/body/div[1]/div[2]/div/div/div/mat-optgroup[1]/mat-option/span")
drop_down_select.click()


drop_down_Province = web.find_element("xpath", "/html/body/app-root/app-appointment/section[2]/div/div[2]/div[1]/div/div[2]/div/mat-select/div/div[1]")
drop_down_Province.click()
time.sleep(2)
drop_down_select_p = web.find_element("xpath", "/html/body/div[1]/div[2]/div/div/div/mat-optgroup[1]/mat-option")
drop_down_select_p.click()


drop_down_district = web.find_element("xpath", "/html/body/app-root/app-appointment/section[2]/div/div[2]/div[1]/div/div[3]/div/mat-select/div/div[1]")
drop_down_district.click()
time.sleep(2)
drop_down_select_d = web.find_element("xpath", "/html/body/div[1]/div[2]/div/div/div/mat-optgroup[4]/mat-option[1]")
drop_down_select_d.click()

time.sleep(2)

drop_down_location = web.find_element("xpath", "/html/body/app-root/app-appointment/section[2]/div/div[2]/div[1]/div/div[4]/div/mat-select/div/div[1]")
drop_down_location.click()
time.sleep(3)
drop_down_select_l = web.find_element("xpath", "/html/body/div[1]/div[2]/div/div/div/mat-option[2]")
drop_down_select_l.click()




# time.sleep(3)
# # import ipdb; ipdb.set_trace()


# submit = web.find_element("xpath", '/html/body/app-root/app-request-service/section[2]/div/div/div[1]/div/form/div/div/div[3]/div[2]/a')
# submit.click()

# email = "pokhrelinfo@gmail.com"
# emailid = web.find_element("xpath", '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/div[1]/div/div[1]/input')
# emailid.send_keys(email)

# phone = "9849937143"
# phoneno = web.find_element("xpath", '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[3]/div/div/div[2]/div/div[1]/div/div[1]/input')
# phoneno.send_keys(phone)

# RadioButtonPeriod = web.find_element("xpath", '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[4]/div/div/div[2]/div[1]/div/span/div/div[2]/label')
# RadioButtonPeriod.click()


# Submit = web.find_element("xpath", '//*[@id="mG61Hd"]/div[2]/div/div[3]/div[1]/div[1]/div/span')
# Submit.click()
