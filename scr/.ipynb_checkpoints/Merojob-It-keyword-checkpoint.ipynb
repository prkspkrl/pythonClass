# %%
from bs4 import BeautifulSoup
import requests

html_text = requests.get('https://merojob.com/search/?q=Developer&start_date=&end_date=').text #.text bring all html text 
# print(html_text)

soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('div', class_ = 'card mt-3 hover-shadow') 
# print(job)

for job in jobs:
    company_name = job.find('h1', class_ = 'text-primary font-weight-bold media-heading h4').text.replace(' ','')
    #replace spece to nothing


    
    skills = job.find('span', itemprop = 'skills')
    if skills is not None:
        f_skill = skills.text.replace(' ','')
    else:
        f_skill = None 

        

    Job_expire = job.find('p', class_ = 'text-primary mb-0').text
    print(Job_expire)
    
    
    
#     print(f"Company Name: {company_name}")
#     print(f"Company Name: {f_skill}")
#     print(f"Company Name: {Job_expire}")
    


    print(f'''Company Name: {company_name}
    Required Skill: {f_skill}
    Job_expire: {Job_expire}
    ''')
# Out:
# Apply Before: 2 weeks, 5 days from now
#
#
# Company Name:
#
# SeniorJAVADeveloper
#
#
#
#     Required Skill:
# Hibernate
# Jquery
# Wildfly
# Angular/React
# Node.Js
# Extjs
# Docker
#
#     Job_expire:
#
# Apply Before: 2 weeks, 5 days from now
#
#
#
#
#
# Apply Before: 6 days, 23 hours from now
#
#
# Company Name:
#
# WebDeveloper
#
#
#
#     Required Skill: None
#     Job_expire:
#
# Apply Before: 6 days, 23 hours from now
#
#
#
#
#
# Apply Before: 4 days, 23 hours from now
#
#
# Company Name:
#
# FullStackDeveloper(.Net)
#
#
#
#     Required Skill:
# React
# .NetCore
# .NetMvc
# Asp.Net
#
#     Job_expire:
#
# Apply Before: 4 days, 23 hours from now
#
#
#
#
#
# Apply Before: 3 days, 23 hours from now
#
#
# Company Name:
#
# SeniorDotNetDeveloper
#
#
#
#     Required Skill:
# Sql
# Communication
# ProblemSolving
# Analytical
# C#
#
#     Job_expire:
#
# Apply Before: 3 days, 23 hours from now
#
#
#
#
#
# Apply Before: 3 days, 23 hours from now
#
#
# Company Name:
#
# SeniorMS-SQLDeveloper
#
#
#
#     Required Skill:
# Troubleshooting
# Communication
# Vbscript
# ProblemSolving
#
#     Job_expire:
#
# Apply Before: 3 days, 23 hours from now
#
#
#
#
#
# Apply Before: 23 hours from now
#
#
# Company Name:
#
# ReactNativeDeveloper
#
#
#
#     Required Skill: None
#     Job_expire:
#
# Apply Before: 23 hours from now

# %%
from bs4 import BeautifulSoup
import requests

html_text = requests.get('https://merojob.com/search/?q=Developer&start_date=&end_date=').text #.text bring all html text 
# print(html_text)

soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('div', class_ = 'card mt-3 hover-shadow') 
# print(job)

for job in jobs:
    company_name = job.find('h1', class_ = 'text-primary font-weight-bold media-heading h4').text.replace(' ','')
    #replace spece to nothing


    
    skills = job.find('span', itemprop = 'skills')
    if skills is not None:
        f_skill = skills.text.strip()
    else:
        f_skill = None 

        

    Job_expire = job.find('p', class_ = 'text-primary mb-0').text
#     print(Job_expire)
    
#     print(f_skill)
    
    
    
    print(f"Company Name: {company_name.strip()}")
    print(f"Required Skill: {f_skill}")
    print(f"Job Expire in : {Job_expire.strip()}")
# Out:
# Company Name: SeniorJAVADeveloper
# Required Skill: Hibernate
# Jquery
# Wildfly
# Angular/React
# Node.Js
# Extjs
# Docker
# Job Expire in : Apply Before: 2 weeks, 5 days from now
# Company Name: WebDeveloper
# Required Skill: None
# Job Expire in : Apply Before: 6 days, 23 hours from now
# Company Name: FullStackDeveloper(.Net)
# Required Skill: React
# .NetCore
# .NetMvc
# Asp.Net
# Job Expire in : Apply Before: 4 days, 23 hours from now
# Company Name: SeniorDotNetDeveloper
# Required Skill: Sql
# Communication
# ProblemSolving
# Analytical
# C#
# Job Expire in : Apply Before: 3 days, 23 hours from now
# Company Name: SeniorMS-SQLDeveloper
# Required Skill: Troubleshooting
# Communication
# Vbscript
# ProblemSolving
# Job Expire in : Apply Before: 3 days, 23 hours from now
# Company Name: ReactNativeDeveloper
# Required Skill: None
# Job Expire in : Apply Before: 23 hours from now
